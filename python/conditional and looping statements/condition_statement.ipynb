# %% [markdown]
# # conditional Statements
#
# # if statement
# # elif statement
# # else statement

# %%
# driving elegibility creteria

age=int(input("enter your age"))
if age>=18:
    print("eligible to drive a car")
else:
        print("not eligible to drive a car")
# Out:
# eligible to drive a car

# %%
ram_height=int(input("enter your age"))
raj_height=int(input("enter your age"))
ada_height=int(input("enter your age"))
if ram_height>raj_height>ada_height:
    print("ram is taller in all")
elif raj_height>ram_height>ada_height:
    print("raj is taller in all")
else:print("ada height is greater in all")
# Out:
# ada height is greater in all

# %% [markdown]
# # nested conditional statements

# %% [markdown]
# # in this satements ek if block ke andr if and else block create hua rahta hai

# %%
age=int(input("enter your age"))
if(age>18):
    if(age<60):
        print("he is able to drive")
    else: print("your are  in older age ")
else:
    print("your are not able to drive")
# Out:
# your are not able to drive

# %%
# whether if the current year is a leap or not
year=int(input("enter year value:"))
if(year%4==0) or (year%100!=0) and (year%400==0):
    print("this is leap year")
else:
    print(" not a leap year ")
# Out:
# this is leap year

# %%
# whether if the current year is a leap or not
year=int(input("enter year value:"))
if year%4==0:
    if year%100==0:
        if(year%400==0):
            print("the current year is aleap year")
        else:print("the current year is not a leap year")   
    else:
        print("year is a leap year")
else :
    print("year is not a leap year")
# Out:
# year is aleap year
