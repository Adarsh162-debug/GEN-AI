# %% [markdown]
# # file Handling

# %% [markdown]
#   technology----> information can be their in ram memeory or it can be stored in a file

# %% [markdown]
# Ram memory-->information will be their temperarily
#
# file--> information will be their permanently

# %% [markdown]
# NLP--> Text Data (sequential Data )--> text format file
#
# Machine learning models--> cat dog image classifier-->png or jpeg--> binary format file
#
# deep learning-->object classifier --> png or jpeg -->Binary format file

# %% [markdown]
# # type of files
# 1. text file-->.txt,docx,etc
#
#
# 2.binary file-->.png,.mp4,.mp3,.mov

# %% [markdown]
# # file Handling
#
#  diary--> read the content from my diary
#
#  1.open my diary
#
#  2.read the content
#
#  3.close the diary
#
# ## writing the content into your diary
#
#  1.open my diary
#
#  2.write the content into the diary
#
#  3.close the diary

# %% [markdown]
#  # file Handling
#
#  1.read the content from my text file in the system

# %%
## open() --> opening your file
# first parameter-->File_name
# second parameter-->mode
# mode --> it decide the way in which we are working with this file
'''Mode-->r -->Reading the content from the file

 Mode--> w--> write the content into the file

 mode-->r+ --> read the content first and then writing the content into the file

 mode--> w+ --> writing the content first and then reading from it '''

# %%
# reading your file
# read()--> reads the content from the file

# %%
f=open('example.txt','r')
content=f.read()
print(content)
f.close( )
# Out:
# hello my name is adarsh baba
# i am your student in grn ai course
# we ar learning anout python as per our pre requirements

# %% [markdown]
# # writing the content into the file
#
#  write()--> it write the content into the the text file
#
#  mode--> w-->content will be overwritten
#
#
#  mode --> a -->content will be added from the end

# %%
f=open('example.txt','w')
f.write('hello we are now writing the content into our file')
f.close()

# %%
#append the information
f=open('example.txt','a')
f.write('\n mode are learning about gen ai pre requirement pythons')
f.close()

# %% [markdown]
# # with
# with -->it will be used for of all opening as a object and there is no requirement for closing the file as well

# %%
with open('example.txt','r') as f:
    content_data=f.read()
    print(content_data)
# Out:
# hello we are now writing the content into our file
#  mode are learning about gen ai pre requirement pythons

# %%
# write me phale ka sara data clear kar deta hai phir input karta hai apna data
with open('example.txt','w') as file:
    file.write("we are exploring about with command in th  python file handling")

# %%
with open('example.txt','a') as f:
    f.write("\n i am exploring in this subject")

# %% [markdown]
# # file handling question

# %%
## write the content into our file line by line --> writelines()

# %%
lines=['first\n','second\n','third\n']
with open ('example.txt','w') as d:
    d.writelines(lines)

# %% [markdown]
# ## mode
# mode--> write the content into the binary file--> wb
#
# mode--> read the content from the binary file --> rb

# %%
data=b'\x00\x01\x03\x04'
with open('example.txt','wb')as binary_data:
    binary_data.write(data)

# %%
# read in binary data
with open('example.txt','rb') as binary_read:
    binary_content=binary_read.read()
    print(binary_data)
# Out:
# <_io.BufferedWriter name='example.txt'>

# %%
# read the content from source.txt file  and then writting the content into another file

with open('source.txt','r') as d:
    content=d.read()

with open('distination.txt','w') as w:
    w.write(content)

# %%
# reading the total lines,total words,total characters from a file--> readlines()
def count_lines(file):
    with open(file,'r') as files:
        lines=files.readlines()
        total_lines=len(lines)
        total_words=sum(len(line.split()) for line in lines)
        total_characters=sum(len(line) for line in lines)
    return total_lines,total_words,total_characters  
 
file_path='total_data.txt'
total_lines,total_words,total_charcaters=count_lines(file_path)
print(f"total lines are :{total_lines} and total words are:{total_words} and total characters are:{total_charcaters}")
# Out:
# total lines are :8 and total words are:25 and total characters are:167

# %% [markdown]
# # readlines()
# readlines -->reads the line in a way  in it is like the lines are stored inside a list ['hello i am amit','i am your gen ai instructor','let us learn python first']

# %% [markdown]
#  # seek()
#  write the  content into a file and then after writing the content into that file we are going to read the content from the file as well -->seek()

# %% [markdown]
# # w+ -->
#  first of all as W is their so it staets that first writing operation will be done and then reading operation will be done
#
# # seek()-->
# it is going to help us to out with reading the content after writing from the starting only

# %%
with open('total_data.txt','w+') as write_read_file:
    write_read_file.write("\n we are looking into w+ operation")
    write_read_file.write("\n it means writing and then reading")
    write_read_file.seek(0)
    content_complete_data=write_read_file.read()
    print(content_complete_data)
# Out:
#  we are looking into w+ operation
#  it means writing and then reading

# %% [markdown]
#  previous data is erase then new data is entered
