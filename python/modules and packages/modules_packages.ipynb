# %% [markdown]
# # modules and packages

# %%
def addition(x,y):
    return x+y

# %%
addition(4,5)
# Out:
# 9

# %% [markdown]
#  i want to use this logic of the function in this file ointo the other files

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
## how complex the logic of a square root function is going to be

# %% [markdown]
# # modules
#  a modules in python is simply a file containing python code(functions,classes or variables) that can be imported and used in other programs

# %% [markdown]
# # numpy-->
# numpy modules is going to help us out with scientific calculation on the array and we can store our data by consuming less space and we can apply the operation with our array a bit more faster as compared to those of the list
#
# --> we can do it in numpy just because numpy is having the collection of functions and attrbutes which can help us to efficiently with the array

# %% [markdown]
# # pandas
#
# pandas we can use when we are going to work with the dataset for cleaning, preprocessing,EDA, analysis with plotting as well

# %%
# syntx || way
import math
math.sqrt(16)
# Out:
# 4.0

# %%
# way2
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
# import star means import all function,methods are access of math
from math import *
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# # A Module:
# 1. A module helps in code organization
# 2. it promotess reusability
# 3. it keeps the code clean and manageable

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
math.factorial(15)
# Out:
# 1307674368000

# %%
import numpy

# %%
list_item=[[1,2,3,4,5]]
numpy_array=numpy.array(list_item)
type(numpy_array)
print(numpy_array)
# Out:
# [[1 2 3 4 5]]

# %%
print(type(numpy_array))
# Out:
# <class 'numpy.ndarray'>

# %%
! pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.11.1-cp314-cp314-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.11.1-cp314-cp314-win_amd64.whl (9.5 MB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 2.2 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.5 MB 2.2 MB/s eta 0:00:01
# ...

# %% [markdown]
#  i am trying to create my own library or own modules and in this library i want the function and the attributes to be created on my own

# %%
## _init_.py is a file that has to be their inside the package folder and this  _init_.PythonFinalizationError

#  file helps us out in defininh our packages and initializng their namespace

# %% [markdown]
# _init_.py file can remaing empty and its completely fine but this file has to be  their
# when we will be creating our new packing into the package folder

# %%
from package_folder.mathematics import addition

# %%
addition(4,8)
# Out:
# 12

# %%
from package_folder.mathematics import *

# %%
substraction(67,12)
# Out:
# 55

# %%
division(8,2)
# Out:
# 4.0

# %%
multiplication(6,4)
# Out:
# 24

# %%
from package_folder.subpacking.sum import *

# %%
sum(23,45,67)
# Out:
# 135
