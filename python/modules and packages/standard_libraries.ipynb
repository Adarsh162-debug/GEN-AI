# %% [markdown]
# # standard libraries in python

# %% [markdown]
# python standard library is a vast collection of modules and packages that come bundlrd with python and it provides us with a vast range of functionalities

# %% [markdown]
#  # math library
#   it is having y=the functionalities for performing mathematical calculations

# %%
from math import *
int_nums=int(input("enter the number whose sqrt rrot you  want to calculate:"))
print(sqrt(int_nums))
# Out:
# 7.0

# %% [markdown]
# # random library
# it is having the functionalities for generating the random values so we call this library as arandom value generator

# %%
import random

# %%
# randint is used  in random method in which it pick the rand value blw the range
print(random.randint(1,100))
# Out:
# 21

# %% [markdown]
# # random.choice()
#  in this type pick random value on th specific range

# %%
print(random.choice(['apple','banana','guava','grapes']))
# Out:
# banana

# %%
# csv library -->most of the time we are going to work with csv files so thats why knowledge
# with csv library functionality matters

# %%
import csv

# %%
with open('example.txt','w',newline='') as  file:
   writer=csv.writer(file)
   writer.writerow(['name','age'])
   writer.writerow(['amit',23])

# %%
with open('example.txt','r') as files:
   reader=csv.reader(files)
   for row in reader:
      print(row)
# Out:
# ['name', 'age']
# ['amit', '23']

# %% [markdown]
# # DATE TIME LIBRARY
# it helps us out with figuring out the current time and date

# %%
from datetime import datetime,timedelta
time_current=datetime.now()
print(time_current)
# Out:
# 2026-09-11 23:41:06.489529

# %%
yesterday_time=time_current-timedelta(days=1)
print(yesterday_time)
# Out:
# 2026-09-10 23:41:06.489529

# %% [markdown]
# # time library
# time--> time library provides us the current times and if you want interpreter to sleep fo rseconds you can do it by using time library

# %%
import time
print(time.time())
# Out:
# 1789150810.9994397

# %% [markdown]
#  if you are writing a piece of code and you want your interpreter to sleep for a number of seconds then you can make the use of sleep function

# %%
print(time.time())
time.sleep(4)
print(time.time())
# Out:
# 1789151007.144906
# 1789151011.1465409

# %% [markdown]
# ## os library,json library,regular expression library

# %%
import os

# %%
## getcwd()--> get current working directory
## getcwd() function provides us with the idea that in which specific directory we are in right now

# %%
print(os.getcwd())
# Out:
# c:\gen ai full course\python\modules and packages

# %%
# mkdir--> it stands for make directory function which can help us out with creating the directory for us

os.mkdir('new_directory')

# %% [markdown]
# # shutil

# %%
import shutil
shutil.copyfile('source.txt','deestination_file.txt')
# Out:
# 'deestination_file.txt'

# %%
with open('deestination_file.txt','r') as file:
    print(file.read())
# Out:
#  hello my name is amit kumar singh
#  and i am your generative Ai instructor
#  we are looking over the functionality of shutil library

# %% [markdown]
# ## json library
#
# when we are going to work with nosql database data then the data inside the nosql database is going to be their in the json format  and along with that when we are going to work with the datasets as well then again these dataset will be consisting of data in the json format itself

# %% [markdown]
#  when we get the json DAta, we get in a json string format so by using json library we can  convert our string data into dictionary format for serializing our data

# %%
import json
data ={"name":"amit","age":25}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
# Out:
# {"name": "amit", "age": 25}
# <class 'str'>

# %%
import json
json_dict=json.loads(json_str)
print(json_dict)
print(type(json_dict))
# Out:
# {'name': 'amit', 'age': 25}
# <class 'dict'>

# %% [markdown]
# # regular expression
#  regular expression is used to retrieve info based on the specific pattern
#  or if the pattern matches

# %%
# to retirive the digit in the text variables
import re
text='hello my name is amit and my password is helloamit12345'
pattern=r'\d+'
match=re.search(pattern,text)
print(match.group())
# Out:
# 12345
