# %% [markdown]
# ## data types

# %%
age=int(input("enter your age"))

# %%
age
# Out:
# 46

# %%
age2=67

# %%
print(type(age2))
# Out:
# <class 'int'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(age+age2)
# Out:
# 113
