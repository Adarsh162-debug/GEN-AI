# %% [markdown]
# # operators

# %% [markdown]
# # types of operators
# 1.Airtmetics operator
# Addition (+)
# substraction(-)
# product or multiplcation(*)
# division(/)
# modulus(%)
# floor(//)
# exponent(a**b)
#
# 2.comparision operator
# grater than
# less than
# greater then equal to
# less than equal too
# double equal to
# not equal to
#
# 3.logical operator
# and
# or
# not

# %%
# addition
a=4
b=21
print(a+b)
# Out:
# 25

# %%
#sunstraction
a=4
b=21
print(a-b)
# Out:
# -17

# %%
# multiply
a=4
b=21
print(a*b)
# Out:
# 84

# %%
#divide
a=4
b=21
print(a/b)
# Out:
# 0.19047619047619047

# %%
# modules
a=4.5
b=2
print(a%b)
# Out:
# 0.5

# %%
# floor
a=34
b=12
print(a//b)
# Out:
# 2

# %%
#exponential
a=4
b=2
print(a**b)
# Out:
# 16

# %% [markdown]
# comparision operators

# %%
# ==
a=4
b=21
print(a==b)
# Out:
# False

# %%
#not equal to
a=4
b=21
print(a!=b)
# Out:
# True

# %%
#greater than
a=4
b=21
print(a>b)
# Out:
# False

# %%
#less than
a=4
b=21
print(a>b)
# Out:
# False

# %%
#<=
a=4
b=21
print(a<=b)
# Out:
# True

# %% [markdown]
# logical operator

# %%
#&
a=12
b=21
c=23

a<b and b<c
# Out:
# True

# %%
#simple caalculator
a=int(input("enter the value"))
b=int(input("enter thr second value"))
operation=input("enter your operation")
if operation =='+':
    print(a+b)
if operation =='-':
    print(a-b)
if operation =='*':
    print(a*b)
if operation =='/':
    print(a/b)
# Out:
# 408
