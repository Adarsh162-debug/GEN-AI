# %% [markdown]
# # streamlit
#  is an open source python library used to build beautiful, interactive web application for data science and machine learning with minimal effort.

# %% [markdown]
# # why to use streamlit
#  --> easy to use
#  --> fast development
#  --> interactive ui elements --> buttons,sliders,text inputs,charts,etc
#
#  -->great for data science --> support pandas, matplotlib,ploty and other libraries
#
#  --> deployment is easy
